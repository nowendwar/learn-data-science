# %%
import numpy as np
import pandas as pd

# %%
na_vals = ['NA', 'Missing']

df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent', na_values=na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')
schema_df.sort_index(inplace=True)

# %%
pd.set_option('display.max_columns', 80)
pd.set_option('display.max_rows', 80)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
schema_df.head()
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...

# %%
schema_df.loc['BetterLife', 'QuestionText']
# Out:
# 'Do you think people born today will have a better life than their parents?'

# %%
high_salary = (df['CompTotal'] > 70000)
countries = ['United States of America', 'India', 'United Kingdom', 'Germany', 'Canada', 'Vietnam']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, ['Country', 'ConvertedComp']]
# Out:
#                    Country  ConvertedComp
# Respondent
# 1           United Kingdom            NaN
# 6                   Canada       366420.0
# 8                    India            NaN
# 10                   India        13293.0
# 12                  Canada            NaN
# ...                    ...            ...
# 84539       United Kingdom            NaN
# 85182               Canada            NaN
# 85961       United Kingdom            NaN
# 86012                India            NaN
# 88377               Canada            NaN
#
# [24059 rows x 2 columns]

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
filt
# Out:
# Respondent
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].map({'Yes': True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})

# %%
df['Hobbyist'].value_counts()
# Out:
# True     71257
# False    17626
# Name: Hobbyist, dtype: int64

# %%
df.sort_values(by=['Country', 'SalaryUSD'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0
# 722         Afghanistan        0.0
# 28638       Afghanistan        0.0
# 6417        Afghanistan        NaN
# 7353        Afghanistan        NaN
# 12310       Afghanistan        NaN
# 26340       Afghanistan        NaN
# 29045       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 37802       Afghanistan        NaN
# 40000       Afghanistan        NaN
# 43106       Afghanistan        NaN
# 44403       Afghanistan        NaN
# 45854       Afghanistan        NaN
# 47110       Afghanistan        NaN
# 49702       Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nsmallest(10, 'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 722                            I am a developer by profession     False
# 28638                          I am a developer by profession      True
# 13825                          I am a developer by profession      True
# 40913                          I am a developer by profession      True
# 30630                          I am a developer by profession      True
# 69049                          I am a developer by profession     False
# 19340       I am not primarily a developer, but I write co...      True
# 16214       I am not primarily a developer, but I write co...      True
# 29355                          I am a developer by profession      True
# 1685                           I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 722         Less than once a month but more than once per ...
# ...

# %%
df.reset_index(inplace=True)
df['SalaryUSD'].head(50)
# Out:
# 0     1000000.0
# 1      153216.0
# 2       19152.0
# 3       17556.0
# 4       14364.0
# 5        7980.0
# 6        4464.0
# 7        3996.0
# 8        1596.0
# 9        1116.0
# 10          0.0
# 11          0.0
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44     187668.0
# 45     114550.0
# 46      74474.0
# 47      60000.0
# 48      57300.0
# 49      41244.0
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# C:\Users\NHPHUC\AppData\Local\Temp\ipykernel_10872\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Respondent     44442.0
# Hobbyist           1.0
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe()
# Out:
#          Respondent     CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04  5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11  1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13  2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00  0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04  2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04  5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05  1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16  2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df['SalaryUSD'].count()
# Out:
# 55823

# %%
df['Hobbyist']
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist'].value_counts()
# Out:
# True     71257
# False    17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# 0        I don't use social media
# 1                        WhatsApp
# 2                        Facebook
# 3                        Facebook
# 4                       Instagram
#                    ...
# 88878                         NaN
# 88879                         NaN
# 88880                         NaN
# 88881                         NaN
# 88882                         NaN
# Name: SocialMedia, Length: 88883, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: Country, Length: 179, dtype: int64

# %%
country_group = df.groupby(['Country'])
country_group

# %%
country_group.get_group('India')
# Out:
#        Respondent                                         MainBranch  \
# 25784       22013                     I am a developer by profession
# 25785       28243                     I am a developer by profession
# 25786       72732  I am not primarily a developer, but I write co...
# 25787       16793                     I am a developer by profession
# 25788       52561                     I am a developer by profession
# ...           ...                                                ...
# 34840       77339                                                NaN
# 34841       79795                                                NaN
# 34842       83862                                                NaN
# 34843       84299                                                NaN
# 34844       86012                                                NaN
#
#        Hobbyist                                        OpenSourcer  \
# 25784      True                                              Never
# ...

# %%
filt = df['Country'] == 'India'

df.loc[filt]['SocialMedia'].value_counts()
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# WeChat 微信                      5
# Hello                          5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts(normalize=True).loc[['India', 'China']]
# Out:
# Country  SocialMedia
# India    WhatsApp                    0.342379
#          YouTube                     0.208405
#          LinkedIn                    0.109355
#          Facebook                    0.096301
#          Instagram                   0.094126
#          Twitter                     0.062063
#          Reddit                      0.054162
#          I don't use social media    0.028627
#          Snapchat                    0.002634
#          Hello                       0.000573
#          WeChat 微信                   0.000573
#          VK ВКонта́кте               0.000458
#          Youku Tudou 优酷              0.000229
#          Weibo 新浪微博                  0.000115
# China    WeChat 微信                   0.670549
#          YouTube                     0.088186
#          Weibo 新浪微博                  0.069884
#          I don't use social media    0.044925
#          Twitter                     0.044925
#          Reddit                      0.019967
# ...

# %%
country_group['SalaryUSD'].median().loc[['India', 'China', 'Germany']]
# Out:
# Country
# India      10080.0
# China      28464.0
# Germany    63016.0
# Name: SalaryUSD, dtype: float64

# %%
country_group['SalaryUSD'].agg(['median', 'mean']).loc[['India', 'China', 'Germany']]
# Out:
#           median           mean
# Country
# India    10080.0   28057.664916
# China    28464.0   57430.421053
# Germany  63016.0  109256.884066

# %%
filt = df['Country'] == 'India'

df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
# country_group['LanguageWorkedWith'].str.contains('Python').sum()

# %%
country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns')
python_df
# Out:
#                                   Country  LanguageWorkedWith
# United States                       20949               10083
# India                                9061                3105
# Germany                              5866                2451
# United Kingdom                       5737                2384
# Canada                               3395                1558
# ...                                   ...                 ...
# North Korea                             1                   0
# Niger                                   1                   1
# Saint Vincent and the Grenadines        1                   0
# Chad                                    1                   0
# Brunei Darussalam                       1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)
python_df
# Out:
#                                   NumRespondents  NumKnowsPython
# United States                              20949           10083
# India                                       9061            3105
# Germany                                     5866            2451
# United Kingdom                              5737            2384
# Canada                                      3395            1558
# ...                                          ...             ...
# North Korea                                    1               0
# Niger                                          1               1
# Saint Vincent and the Grenadines               1               0
# Chad                                           1               0
# Brunei Darussalam                              1               0
#
# [179 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython'] / python_df['NumRespondents']) * 100

# %%
python_df
# Out:
#                                   NumRespondents  NumKnowsPython  \
# United States                              20949           10083
# India                                       9061            3105
# Germany                                     5866            2451
# United Kingdom                              5737            2384
# Canada                                      3395            1558
# ...                                          ...             ...
# North Korea                                    1               0
# Niger                                          1               1
# Saint Vincent and the Grenadines               1               0
# Chad                                           1               0
# Brunei Darussalam                              1               0
#
#                                   PctKnowsPython
# United States                          48.131176
# India                                  34.267741
# ...

# %%
python_df.sort_values(by=['PctKnowsPython'], ascending=False, inplace=True)

# %%
python_df.head()
# Out:
#                        NumRespondents  NumKnowsPython  PctKnowsPython
# Sao Tome and Principe               1               1      100.000000
# Niger                               1               1      100.000000
# Dominica                            1               1      100.000000
# Timor-Leste                         1               1      100.000000
# Turkmenistan                        7               6       85.714286

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    391.000000
# NumKnowsPython    182.000000
# PctKnowsPython     46.547315
# Name: Japan, dtype: float64

# %%
# df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].unique()
# Out:
# array(['Less than 1 year', '7', '2', '6', '3', '4', '10', '36', '1', nan,
#        'More than 50 years', '20', '9', '5', '8', '31', '28', '15', '13',
#        '12', '17', '18', '21', '35', '14', '25', '11', '19', '22', '23',
#        '40', '39', '30', '43', '27', '33', '29', '24', '34', '16', '32',
#        '26', '38', '44', '41', '45', '37', '47', '42', '46', '48', '50',
#        '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)

# %%
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array([0, '7', '2', '6', '3', '4', '10', '36', '1', nan, 51, '20', '9',
#        '5', '8', '31', '28', '15', '13', '12', '17', '18', '21', '35',
#        '14', '25', '11', '19', '22', '23', '40', '39', '30', '43', '27',
#        '33', '29', '24', '34', '16', '32', '26', '38', '44', '41', '45',
#        '37', '47', '42', '46', '48', '50', '49'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].describe()
# Out:
# count    87938.000000
# mean        11.662114
# std          9.152772
# min          0.000000
# 25%          5.000000
# 50%          9.000000
# 75%         15.000000
# max         51.000000
# Name: YearsCode, dtype: float64

# %%
df.set_index('Respondent', inplace=True)

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
india_df.head()
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 16793                          I am a developer by profession      True
# 52561                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 22013                                                   Never
# 28243                              Once a month or more often
# 72732       Less than once a month but more than once per ...
# 16793                              Once a month or more often
# 52561                                                   Never
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
india_df.to_csv('data/modified_csv.csv')

# %%
india_df.to_csv('data/modified_csv.csv', sep='\t')

# %%
india_df.to_excel('data/modified.xlsx')

# %%
test = pd.read_excel('data/modified.xlsx', index_col='Respondent')

# %%
test.head()
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 16793                          I am a developer by profession      True
# 52561                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 22013                                                   Never
# 28243                              Once a month or more often
# 72732       Less than once a month but more than once per ...
# 16793                              Once a month or more often
# 52561                                                   Never
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
india_df.to_json('data/modified.json', orient='records', lines=True)

# %%
test = pd.read_json('data/modified.json', orient='records', lines=True)

# %%
test.head()
# Out:
#                                           MainBranch  Hobbyist  \
# 0                     I am a developer by profession      True
# 1                     I am a developer by profession      True
# 2  I am not primarily a developer, but I write co...     False
# 3                     I am a developer by profession      True
# 4                     I am a developer by profession      True
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                         Once a month or more often
# 4                                              Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  OSS is, on average, of HIGHER quality than pro...
# 2  OSS is, on average, of LOWER quality than prop...
# ...

# %%
from sqlalchemy import create_engine, text as sql_text
import psycopg2

# %%
engine = create_engine('postgresql://postgres:hoangphuc@localhost:5432/pandas')

# %%
india_df.to_sql('sample_table', engine, if_exists='replace')
# Out:
# 229

# %%
#  sql_df = pd.read_sql('sample_table', engine, index_col='Respondent')

# %%
# https://stackoverflow.com/questions/75309237/read-sql-query-throws-optionengine-object-has-no-attribute-execute-with?noredirect=1&lq=1

query = 'SELECT * FROM sample_table'
sql_df = pd.read_sql_query(con=engine.connect(), sql=sql_text(query), index_col='Respondent')

# %%
sql_df.head()
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 16793                          I am a developer by profession      True
# 52561                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 22013                                                   Never
# 28243                              Once a month or more often
# 72732       Less than once a month but more than once per ...
# 16793                              Once a month or more often
# 52561                                                   Never
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
posts_df = pd.read_csv('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python-CSV/names.csv')

# %%
posts_df
# Out:
#    first_name       last_name                           email
# 0        John             Doe         john-doe@bogusemail.com
# 1        Mary  Smith-Robinson       maryjacobs@bogusemail.com
# 2        Dave           Smith        davesmith@bogusemail.com
# 3        Jane          Stuart       janestuart@bogusemail.com
# 4         Tom          Wright        tomwright@bogusemail.com
# 5       Steve        Robinson    steverobinson@bogusemail.com
# 6      Nicole          Jacobs     nicolejacobs@bogusemail.com
# 7        Jane          Wright       janewright@bogusemail.com
# 8        Jane             Doe          janedoe@bogusemail.com
# 9        Kurt          Wright       kurtwright@bogusemail.com
# 10       Kurt        Robinson     kurtrobinson@bogusemail.com
# 11       Jane         Jenkins      janejenkins@bogusemail.com
# 12       Neil        Robinson     neilrobinson@bogusemail.com
# 13        Tom       Patterson     tompatterson@bogusemail.com
# ...
